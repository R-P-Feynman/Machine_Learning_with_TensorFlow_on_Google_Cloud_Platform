# %% [markdown]
# # Neural Network

# %% [markdown]
# **Learning Objectives:**
#   * Use the `DNNRegressor` class in TensorFlow to predict median housing price

# %% [markdown]
# The data is based on 1990 census data from California. This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.
# <p>
# Let's use a set of features to predict house value.

# %% [markdown]
# ## Set Up
# In this first cell, we'll load the necessary libraries.

# %%
import math
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Next, we'll load our data set.

# %%
df = pd.read_csv("https://storage.googleapis.com/ml_universities/california_housing_train.csv", sep=",")

# %% [markdown]
# ## Examine the data
#
# It's a good idea to get to know your data a little bit before you work with it.
#
# We'll print out a quick summary of a few useful statistics on each column.
#
# This will include things like mean, standard deviation, max, min, and various quantiles.

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# min           3.0         1.0            0.5             14999.0
# 25%         790.0       282.0            2.6            119400.0
# 50%        1167.0       409.0            3.5            180400.0
# 75%        1721.0       605.2            4.8            265000.0
# max       35682.0      6082.0           15.0            500001.0

# %% [markdown]
# This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.  Let's create a different, more appropriate feature.  Because we are predicing the price of a single house, we should try to make all our features correspond to a single house as well

# %%
df['num_rooms'] = df['total_rooms'] / df['households']
df['num_bedrooms'] = df['total_bedrooms'] / df['households']
df['persons_per_house'] = df['population'] / df['households']
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value  num_rooms  \
# count     17000.0     17000.0        17000.0             17000.0    17000.0
# mean       1429.6       501.2            3.9            207300.9        5.4
# std        1147.9       384.5            1.9            115983.8        2.5
# min           3.0         1.0            0.5             14999.0        0.8
# 25%         790.0       282.0            2.6            119400.0        4.4
# 50%        1167.0       409.0            3.5            180400.0        5.2
# 75%        1721.0       605.2            4.8            265000.0        6.1
# max       35682.0      6082.0           15.0            500001.0      141.9
#
#        num_bedrooms  persons_per_house
# count       17000.0            17000.0
# mean            1.1                3.0
# std             0.5                4.0
# min             0.3                0.7
# 25%             1.0                2.4
# 50%             1.0                2.8
# 75%             1.1                3.3
# max            34.1              502.5

# %%
df.drop(['total_rooms', 'total_bedrooms', 'population', 'households'], axis = 1, inplace = True)
df.describe()
# Out:
#        longitude  latitude  housing_median_age  median_income  \
# count    17000.0   17000.0             17000.0        17000.0
# mean      -119.6      35.6                28.6            3.9
# std          2.0       2.1                12.6            1.9
# min       -124.3      32.5                 1.0            0.5
# 25%       -121.8      33.9                18.0            2.6
# 50%       -118.5      34.2                29.0            3.5
# 75%       -118.0      37.7                37.0            4.8
# max       -114.3      42.0                52.0           15.0
#
#        median_house_value  num_rooms  num_bedrooms  persons_per_house
# count             17000.0    17000.0       17000.0            17000.0
# mean             207300.9        5.4           1.1                3.0
# std              115983.8        2.5           0.5                4.0
# min               14999.0        0.8           0.3                0.7
# 25%              119400.0        4.4           1.0                2.4
# 50%              180400.0        5.2           1.0                2.8
# 75%              265000.0        6.1           1.1                3.3
# max              500001.0      141.9          34.1              502.5

# %% [markdown]
# ## Build a neural network model
#
# In this exercise, we'll be trying to predict `median_house_value`. It will be our label (sometimes also called a target). We'll use the remaining columns as our input features.
#
# To train our model, we'll first use the [LinearRegressor](https://www.tensorflow.org/api_docs/python/tf/contrib/learn/LinearRegressor) interface. Then, we'll change to DNNRegressor

# %%
featcols = {
  colname : tf.feature_column.numeric_column(colname) \
    for colname in 'housing_median_age,median_income,num_rooms,num_bedrooms,persons_per_house'.split(',')
}
# Bucketize lat, lon so it's not so high-res; California is mostly N-S, so more lats than lons
featcols['longitude'] = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('longitude'),
                                                   np.linspace(-124.3, -114.3, 5).tolist())
featcols['latitude'] = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'),
                                                  np.linspace(32.5, 42, 10).tolist())

# %%
featcols.keys()
# Out:
# dict_keys(['median_income', 'persons_per_house', 'longitude', 'num_rooms', 'num_bedrooms', 'housing_median_age', 'latitude'])

# %%
# Split into train and eval
msk = np.random.rand(len(df)) < 0.8
traindf = df[msk]
evaldf = df[~msk]

SCALE = 100000
BATCH_SIZE= 100
OUTDIR = './housing_trained'
train_input_fn = tf.estimator.inputs.pandas_input_fn(x = traindf[list(featcols.keys())],
                                                    y = traindf["median_house_value"] / SCALE,
                                                    num_epochs = None,
                                                    batch_size = BATCH_SIZE,
                                                    shuffle = True)
eval_input_fn = tf.estimator.inputs.pandas_input_fn(x = evaldf[list(featcols.keys())],
                                                    y = evaldf["median_house_value"] / SCALE,  # note the scaling
                                                    num_epochs = 1, 
                                                    batch_size = len(evaldf), 
                                                    shuffle=False)

# %%
# Linear Regressor
def train_and_evaluate(output_dir, num_train_steps):
  myopt = tf.train.FtrlOptimizer(learning_rate = 0.01) # note the learning rate
  estimator = tf.estimator.LinearRegressor(
                       model_dir = output_dir, 
                       feature_columns = featcols.values(),
                       optimizer = myopt)
  
  #Add rmse evaluation metric
  def rmse(labels, predictions):
    pred_values = tf.cast(predictions['predictions'],tf.float64)
    return {'rmse': tf.metrics.root_mean_squared_error(labels*SCALE, pred_values*SCALE)}
  estimator = tf.contrib.estimator.add_metrics(estimator,rmse)
  
  train_spec=tf.estimator.TrainSpec(
                       input_fn = train_input_fn,
                       max_steps = num_train_steps)
  eval_spec=tf.estimator.EvalSpec(
                       input_fn = eval_input_fn,
                       steps = None,
                       start_delay_secs = 1, # start evaluating after N seconds
                       throttle_secs = 10,  # evaluate every N seconds
                       )
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# Run training    
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time
train_and_evaluate(OUTDIR, num_train_steps = (100 * len(traindf)) / BATCH_SIZE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7efbcd6be3c8>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_train_distribute': None, '_task_type': 'worker', '_log_step_count_steps': 100, '_global_id_in_cluster': 0, '_service': None, '_num_ps_replicas': 0, '_is_chief': True, '_session_config': None, '_save_checkpoints_secs': 600, '_task_id': 0, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_model_dir': './housing_trained', '_master': '', '_keep_checkpoint_max': 5, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7efbcd6be320>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_train_distribute': None, '_task_type': 'worker', '_session_config': None, '_global_id_in_cluster': 0, '_service': None, '_save_summary_steps': 100, '_is_chief': True, '_log_step_count_steps': 100, '_save_checkpoints_secs': 600, '_task_id': 0, '_num_ps_replicas': 0, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_model_dir': './housing_trained', '_master': '', '_keep_checkpoint_max': 5, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 10 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./housing_trained/model.ckpt.
# INFO:tensorflow:step = 1, loss = 568.711
# INFO:tensorflow:global_step/sec: 43.1009
# INFO:tensorflow:step = 101, loss = 102.370865 (2.327 sec)
# INFO:tensorflow:global_step/sec: 95.8796
# INFO:tensorflow:step = 201, loss = 70.59299 (1.041 sec)
# INFO:tensorflow:global_step/sec: 99.6046
# INFO:tensorflow:step = 301, loss = 118.698326 (1.004 sec)
# INFO:tensorflow:global_step/sec: 218.076
# INFO:tensorflow:step = 401, loss = 70.21206 (0.456 sec)
# INFO:tensorflow:global_step/sec: 91.9638
# INFO:tensorflow:step = 501, loss = 112.79996 (1.092 sec)
# INFO:tensorflow:Saving checkpoints for 514 into ./housing_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 68.00384.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-29-15:04:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-514
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-29-15:04:06
# INFO:tensorflow:Saving dict for global step 514: average_loss = 0.7276426, global_step = 514, loss = 2467.436, rmse = 85301.98
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-514
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 515 into ./housing_trained/model.ckpt.
# INFO:tensorflow:step = 515, loss = 48.027786
# INFO:tensorflow:global_step/sec: 49.8595
# INFO:tensorflow:step = 615, loss = 37.770817 (2.018 sec)
# INFO:tensorflow:global_step/sec: 96.522
# INFO:tensorflow:step = 715, loss = 149.18886 (1.034 sec)
# INFO:tensorflow:global_step/sec: 96.7105
# INFO:tensorflow:step = 815, loss = 60.519413 (1.037 sec)
# INFO:tensorflow:global_step/sec: 93.546
# INFO:tensorflow:step = 915, loss = 75.16786 (1.069 sec)
# INFO:tensorflow:Saving checkpoints for 950 into ./housing_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 56.19595.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-29-15:04:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-950
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-29-15:04:25
# INFO:tensorflow:Saving dict for global step 950: average_loss = 0.64589345, global_step = 950, loss = 2190.2246, rmse = 80367.49
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-950
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 951 into ./housing_trained/model.ckpt.
# INFO:tensorflow:step = 951, loss = 66.86401
# INFO:tensorflow:global_step/sec: 51.1353
# INFO:tensorflow:step = 1051, loss = 25.094755 (1.967 sec)
# INFO:tensorflow:global_step/sec: 83.2311
# INFO:tensorflow:step = 1151, loss = 119.08546 (1.194 sec)
# INFO:tensorflow:global_step/sec: 97.12
# INFO:tensorflow:step = 1251, loss = 42.21336 (1.034 sec)
# INFO:tensorflow:Saving checkpoints for 1307 into ./housing_trained/model.ckpt.
# INFO:tensorflow:Loss for final step:
# INFO:tensorflow:global_step/sec: 284.213
# INFO:tensorflow:step = 12780, loss = 77.80354 (0.352 sec)
# INFO:tensorflow:global_step/sec: 300.742
# INFO:tensorflow:step = 12880, loss = 45.415714 (0.332 sec)
# INFO:tensorflow:global_step/sec: 267.356
# INFO:tensorflow:step = 12980, loss = 55.64469 (0.376 sec)
# INFO:tensorflow:global_step/sec: 289.812
# INFO:tensorflow:step = 13080, loss = 47.883076 (0.345 sec)
# INFO:tensorflow:global_step/sec: 308.385
# INFO:tensorflow:step = 13180, loss = 109.520256 (0.323 sec)
# INFO:tensorflow:global_step/sec: 264.373
# INFO:tensorflow:step = 13280, loss = 40.522617 (0.380 sec)
# INFO:tensorflow:global_step/sec: 292.003
# INFO:tensorflow:step = 13380, loss = 67.50599 (0.340 sec)
# INFO:tensorflow:Saving checkpoints for 13476 into ./housing_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 28.784191.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-29-15:06:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-13476
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-29-15:06:42
# INFO:tensorflow:Saving dict for global step 13476: average_loss = 0.5564888, global_step = 13476, loss = 1887.0536, rmse = 74598.17
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-13476
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13477 into ./housing_trained/model.ckpt.
# INFO:tensorflow:step = 13477, loss = 47.05056
# INFO:tensorflow:global_step/sec: 177.524
# INFO:tensorflow:step = 13577, loss = 46.88077 (0.570 sec)
# INFO:tensorflow:Saving checkpoints for 13609 into ./housing_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 64.39432.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-29-15:06:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./housing_trained/model.ckpt-13609
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-05-29-15:06:45
# INFO:tensorflow:Saving dict for global step 13609: average_loss = 0.5550071, global_step = 13609, loss = 1882.029, rmse = 74498.79

# %%
# DNN Regressor
def train_and_evaluate(output_dir, num_train_steps):
  myopt = tf.train.FtrlOptimizer(learning_rate = 0.01) # note the learning rate
  estimator = tf.estimator.DNNRegressor(model_dir = output_dir,
                                hidden_units = [100, 50, 20],
                                feature_columns = featcols.values(),
                                optimizer = myopt,
                                dropout = 0.1)
  
  #Add rmse evaluation metric
  def rmse(labels, predictions):
    pred_values = tf.cast(predictions['predictions'],tf.float64)
    return {'rmse': tf.metrics.root_mean_squared_error(labels*SCALE, pred_values*SCALE)}
  estimator = tf.contrib.estimator.add_metrics(estimator,rmse)
  
  train_spec=tf.estimator.TrainSpec(
                       input_fn = train_input_fn,
                       max_steps = num_train_steps)
  eval_spec=tf.estimator.EvalSpec(
                       input_fn = eval_input_fn,
                       steps = None,
                       start_delay_secs = 1, # start evaluating after N seconds
                       throttle_secs = 10,  # evaluate every N seconds
                       )
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# Run training    
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time
tf.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
train_and_evaluate(OUTDIR, num_train_steps = (100 * len(traindf)) / BATCH_SIZE)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7efbc8950a20>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_train_distribute': None, '_task_type': 'worker', '_log_step_count_steps': 100, '_global_id_in_cluster': 0, '_service': None, '_num_ps_replicas': 0, '_is_chief': True, '_session_config': None, '_save_checkpoints_secs': 600, '_task_id': 0, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_model_dir': './housing_trained', '_master': '', '_keep_checkpoint_max': 5, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x